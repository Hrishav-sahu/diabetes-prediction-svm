# %% [markdown]
# Hrishav Sahu
#
# 2024019621

# %% [markdown]
# # **Support Vector Machine**
# A Support Vector Machine (SVM) is a supervised machine learning algorithm that finds an optimal hyperplane (a decision boundary) to separate two or more classes of data points in a high-dimensional space, maximizing the margin or distance between the closest points of different classes (the support vectors). SVMs are used for both classification and regression tasks, working well with high-dimensional data and handling non-linear problems through a technique called the kernel trick

# %% [markdown]
# ## Work flow
# 1.Diabetes data
# 2.Data preprocessing
# 3.Train Test Split
# 4.Support Vector Machine Classifer

# %% [markdown]
# #Import the dependencies

# %%
import numpy as np   #for array functions
import pandas as pd   #for dataframes
from sklearn.preprocessing import StandardScaler  #used to standardize the data to a common range
from sklearn.model_selection import train_test_split  #To split the data in to training and test data
from sklearn import svm  #Support vector Machine
from sklearn.metrics import accuracy_score  #

# %% [markdown]
# # Data Collection and Analysis
#
# PIMA Diabetes Dataset

# %%
# Loading the dataset to a pandas dataframe
diabetes_dataset = pd.read_csv('/content/diabetes.csv')

# Printing the first 5 rows of the dataset
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# No of rows and columns  in the dataset
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
# Getting the statistical measures of the data
diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# Finding the count of results of the column "Outcome"
diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# 0 => Non Diabetic
#
# 1 => Diabetic

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
#  Seperate the Data and Lables
X = diabetes_dataset.drop(columns = 'Outcome', axis=1)      # input variabe
Y = diabetes_dataset['Outcome']                             # target variable

# %%
print(X)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# # Data Sandardization

# %%
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(X)    # or we can use scaler.fit_transform

print(standardized_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X = standardized_data
# Y = diabetes_dataset['Outcome']

# %%
print(X)
print(Y)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# # Train-Test Data Splitting

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, stratify=Y, random_state=2)


print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (537, 8) (231, 8)

# %% [markdown]
# # Training the Model

# %%
svmclassifier = svm.SVC(kernel='linear')

# Train the SVM classifier
svmclassifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# Accuracy score on the training data
X_train_pred = svmclassifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_pred, Y_train)

# %%
print('Accuracy Score for Training data : ',training_data_accuracy)
# Out:
# Accuracy Score for Training data :  0.7821229050279329

# %%
# Accuracy score on the test data
X_test_pred = svmclassifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_pred, Y_test)

# %%
print('Accuracy Score for Test data : ',test_data_accuracy)
# Out:
# Accuracy Score for Test data :  0.7748917748917749

# %% [markdown]
# # Prediction System

# %%
input_data = (1,172,68,49,579,42.4,0.702,28)  # copied one row from the dataset

# Change the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# Reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# Standardize the input data
std_data = scaler.transform(input_data_reshaped)
print(std_data)

prediction = svmclassifier.predict(std_data)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic.')
else:
  print('The person is diabetic.')
# Out:
# [[-0.84488505  1.59945528 -0.05715025  1.78546278  4.33450617  1.32090213
#    0.69500088 -0.44593516]]
# [1]
# The person is diabetic.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Visualization

# %% [markdown]
# This will give you:
#
# *   Distribution of diabetes outcomes
#
# *   Correlation heatmap between features
#
# *   Histograms of important predictors
#
# *   Boxplots showing difference by diabetes outcome
#
# *   Pairplot to see feature interactions

# %%
# Import required libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load dataset (adjust variable if already loaded)
df = pd.read_csv("diabetes.csv")   # replace with your dataset path if needed

# 1. Check distribution of target variable
plt.figure(figsize=(6,4))
sns.countplot(x='Outcome', data=df, palette="Set2")
plt.title("Distribution of Diabetes Outcome (0 = No, 1 = Yes)")
plt.show()
print()

# 2. Correlation heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
print()


# 3. Distribution of key features
features = ["Glucose", "BloodPressure", "BMI", "Age"]
plt.figure(figsize=(12,8))
for i, col in enumerate(features, 1):
    plt.subplot(2,2,i)
    sns.histplot(df[col], kde=True, bins=30, color="skyblue")
    plt.title(f"Distribution of {col}")
plt.tight_layout()
plt.show()
print()


# 4. Boxplot of features vs Outcome
plt.figure(figsize=(12,8))
for i, col in enumerate(features, 1):
    plt.subplot(2,2,i)
    sns.boxplot(x="Outcome", y=col, data=df, palette="Set3")
    plt.title(f"{col} vs Outcome")
plt.tight_layout()
plt.show()
print()


# 5. Pairplot of selected features
sns.pairplot(df[["Glucose","BMI","Age","Outcome"]], hue="Outcome", palette="husl")
plt.suptitle("Pairplot of Key Features", y=1.02)
plt.show()
print()
# Out:
# /tmp/ipython-input-1327948490.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Outcome', data=df, palette="Set2")
# /tmp/ipython-input-1327948490.py:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Outcome", y=col, data=df, palette="Set3")
# /tmp/ipython-input-1327948490.py:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Outcome", y=col, data=df, palette="Set3")
# /tmp/ipython-input-1327948490.py:40: FutureWarning:
#
# ...
